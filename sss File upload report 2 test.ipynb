# %%
##view RAW Data
import pandas as pd
import numpy as np
df= pd.read_excel(r'C:\Users\arvinmvn\Desktop\AWS SAMMI Reports\AWS Data adherence Report\AWS Verification Data Adherence Week 34.xlsx',)
df.head()
# Out:
#     User ID  Audio Length  Velocity Quip  Quality Quip
# 0  cliffpal  00:01:35.341            1.0           NaN
# 1  cliffpal  00:08:02.837            1.0           NaN
# 2  cliffpal  00:05:06.000            1.0           NaN
# 3  cliffpal  00:00:51.180            1.0           NaN
# 4  cliffpal  00:03:01.080            1.0           NaN

# %%
df.insert(2, "File Count", 1)
df.head()
# Out:
#     User ID  Audio Length  File Count  Velocity Quip  Quality Quip
# 0  cliffpal  00:01:35.341           1            1.0           NaN
# 1  cliffpal  00:08:02.837           1            1.0           NaN
# 2  cliffpal  00:05:06.000           1            1.0           NaN
# 3  cliffpal  00:00:51.180           1            1.0           NaN
# 4  cliffpal  00:03:01.080           1            1.0           NaN

# %%
df.columns
# Out:
# Index(['User ID', 'Audio Length', 'File Count', 'Velocity Quip',
#        'Quality Quip'],
#       dtype='object')

# %%
##pivot for file counts
table = pd.pivot_table(df, values=['Velocity Quip', 'Quality Quip'], index=['User ID'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
pd.set_option('display.max_rows', df.shape[0]+1)
table
# Out:
#           Quality Quip  Velocity Quip
# User ID
# cliffpal            44             45
# dennypau            58             58
# devarapr            51             52
# djaga               72             73
# gopinana            49             49
# jhus                56             56
# keerdoss            74             75
# mhaaami             49             50
# mmzsai               2              3
# ntox                80             81
# pdikcha             50             51
# vsreevat             1              2

# %%
##create list of DA names


table_AL = pd.pivot_table(df, values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
pd.set_option('display.max_rows', df.shape[0]+1)
table_AL
# Out:
#                        Quality Quip  Velocity Quip
# User ID  Audio Length
# cliffpal 00:00:08.720             1              1
#          00:00:10.560             1              1
#          00:00:14.421             1              1
#          00:00:20.015             1              1
#          00:00:25.020             1              1
#          00:00:25.760             1              1
#          00:00:26.910             1              1
#          00:00:30.000             1              1
#          00:00:32.213             1              1
#          00:00:33.180             1              1
#          00:00:34.416             1              1
#          00:00:40.700             1              1
#          00:00:44.580             0              1
#          00:00:48.000             1              1
#          00:00:51.180             1              1
#          00:00:54.600             1              1
#          00:00:56.400             1              1
# ...

# %%
list= df['User ID'].unique().tolist()
list
# Out:
# ['cliffpal',
#  'dennypau',
#  'devarapr',
#  'djaga',
#  'jhus',
#  'gopinana',
#  'keerdoss',
#  'mhaaami',
#  'mmzsai',
#  'pdikcha',
#  'ntox',
#  'vsreevat']

# %%
##view pivot:- working code for pivoting the table with audio lenth in index as well sss
import win32com.client as win32
for i in range(0,len(list)):
    table_sss = pd.pivot_table(df[df['User ID']== list[i]], values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
    pd.set_option('display.max_rows', df.shape[0]+1)
    #print(table_sss)
    ##email to DAs :- one click still in pipeline

    outlook = win32.Dispatch('outlook.application')
    mail = outlook.CreateItem(0)
    mail.Subject = 'AWS File Upload Report'
    #mail.To='arvinmvn@amazon.com'
    mail.To = list[i]+'@amazon.com'  
    mail.CC = 'czvij@amazon.com'
    
## i-> position of data in dataframe
    mail.HTMLBody = '''<h3>Hi, Please find your file uploads for the week.</h3>
                   {}'''.format(table_sss.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render())  ## : i + 1 increment 1 of index 
# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

    mail.Send()

# %%
len(table.index.get_level_values('User ID'))
# Out:
# 12
