# %%
##view RAW Data
import pandas as pd
import numpy as np
df= pd.read_excel(r'C:\Users\arvinmvn\Desktop\AWS SAMMI Reports\AWS Data adherence Report\AWS Verification Data Adherence Week 21.xlsx',)
df.head(100)
# Out:
#      User ID  Audio Length  Quality Quip  Velocity Quip
# 0   keerdoss  00:38:23.419           1.0            NaN
# 1   keerdoss  00:01:27.600           1.0            NaN
# 2   keerdoss  00:15:12.528           1.0            NaN
# 3   keerdoss  00:00:12.000           1.0            NaN
# 4   keerdoss  00:04:53.400           1.0            NaN
# ..       ...           ...           ...            ...
# 95     nvemn  00:00:30.037           1.0            NaN
# 96     nvemn  00:00:14.344           1.0            NaN
# 97     nvemn  00:00:39.980           1.0            NaN
# 98     nvemn  00:00:07.380           1.0            NaN
# 99     nvemn  00:01:13.008           1.0            NaN
#
# [100 rows x 4 columns]

# %%
df.insert(2, "File Count", 1)
df.head()
# Out:
#     User ID  Audio Length  File Count  Quality Quip  Velocity Quip
# 0  keerdoss  00:38:23.419           1           1.0            NaN
# 1  keerdoss  00:01:27.600           1           1.0            NaN
# 2  keerdoss  00:15:12.528           1           1.0            NaN
# 3  keerdoss  00:00:12.000           1           1.0            NaN
# 4  keerdoss  00:04:53.400           1           1.0            NaN

# %%
df.columns
# Out:
# Index(['User ID', 'Audio Length', 'File Count', 'Quality Quip',
#        'Velocity Quip'],
#       dtype='object')

# %%
##pivot for file counts
table = pd.pivot_table(df, values=['Velocity Quip', 'Quality Quip'], index=['User ID'], columns= [] ,margins=True,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
pd.set_option('display.max_rows', df.shape[0]+1)
table
# Out:
#           Quality Quip  Velocity Quip
# User ID
# cliffpal            50             52
# devarapr            52             53
# djaga               39             39
# gopinana            39             40
# jhus                36             37
# keerdoss            40             41
# mhaaami             22             23
# nvemn               51             52
# pdikcha             29             30
# ranrm               12             16
# total                0              0

# %%
##create list of DA names

for j in range (0,len(table)):
    list = ['cliffpal','dennypau','devarapr','djaga','gopinana','jhus','keerdoss','mhaaami','nvemn','pdikcha','ranrm']
    #list= ['arvinmvn','keerdoss']
    print(list[j])
# Out:
# cliffpal
# dennypau
# devarapr
# djaga
# gopinana
# jhus
# keerdoss
# mhaaami
# nvemn
# pdikcha
# ranrm

# %%
##check if data is correct
list[1]
# Out:
# 'dennypau'

# %%
## Iterate the table one by one, filter out the list on user level basis and drop the data, share bulk mails to the team.
for i in range (0,len(table)):
    for j in range (0,len(table)):
        list = ['cliffpal','dennypau','devarapr','djaga','gopinana','jhus','keerdoss','mhaaami','nvemn','pdikcha','ranrm']
        table_sss= pd.pivot_table(df[df['User ID']==list[j]], values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
        pd.set_option('display.max_rows', df.shape[0]+1)
        print(table_sss)
# Out:
#                        Quality Quip  Velocity Quip
# User ID  Audio Length
# cliffpal 00:00:11.304             1              1
#          00:00:12.010             1              1
#          00:00:13.333             1              1
#          00:00:13.600             1              1
#          00:00:17.920             1              1
#          00:00:18.900             1              1
#          00:00:20.100             1              1
#          00:00:21.120             1              1
#          00:00:21.919             1              1
#          00:00:29.580             1              1
#          00:00:30.000             1              1
#          00:00:30.850             1              1
#          00:00:33.120             1              1
#          00:00:34.640             1              1
#          00:00:39.420             1              1
#          00:00:39.960             1              1
#          00:00:40.400             1              1
# ...

# %%
##view pivot:- working code for pivoting the table with audio lenth in index as well sss
import win32com.client as win32
for j in range (0,len(table)):
    for i in range (0,len(table)):
        list = ['cliffpal','dennypau','devarapr','djaga','gopinana','jhus','keerdoss','mhaaami','nvemn','pdikcha','ranrm']
        #list= ['arvinmvn','keerdoss']
        table_sss= pd.pivot_table(df[df['User ID']==list[j]], values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
        pd.set_option('display.max_rows', df.shape[0]+1)
    #print(table_sss)
    ##email to DAs :- one click still in pipeline

    outlook = win32.Dispatch('outlook.application')
    mail = outlook.CreateItem(0)
    mail.Subject = 'AWS File Upload Report'
    mail.To = str(list[j])+'@amazon.com' 
    mail.CC = 'thenmozs@amazon.com'
    
## i-> position of data in dataframe
    mail.HTMLBody = '''<h3>Hi, Please find your file uploads for the week.</h3>
                   {}'''.format(table_sss.to_html())  ## : i + 1 increment 1 of index 
# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

    mail.Send()

# %%
##view pivot:- working code for pivoting the table with audio lenth in index as well sss

for j in range (0,len(table)-1):
    for i in range (0,len(table)):
        list = ['cliffpal','dennypau','devarapr','djaga','gopinana','jhus','keerdoss','mhaaami','nvemn','pdikcha','ranrm']
    
        table_sss= pd.pivot_table(df[df['User ID']==list[j]], values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
        pd.set_option('display.max_rows', df.shape[0]+1)
    print(table_sss)
