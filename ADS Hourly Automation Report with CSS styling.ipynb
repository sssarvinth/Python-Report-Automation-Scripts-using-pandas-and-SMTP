# %%
## import the liberaries
import pandas as pd
import numpy as np

# %%
## Read the files
df_sheet1= pd.read_excel(r'C:\Users\arvinmvn\Desktop\ADS SM analysis\Hourly Throughput Automation_Test_Data.xlsx',sheet_name='Sheet1')
df_sheet2= pd.read_excel(r'C:\Users\arvinmvn\Desktop\ADS SM analysis\Hourly Throughput Automation_Test_Data.xlsx',sheet_name='Sheet2')
df_sheet3= pd.read_excel(r'C:\Users\arvinmvn\Desktop\ADS SM analysis\Hourly Throughput Automation_Test_Data.xlsx',sheet_name='Sheet3')

# %%
## Read sheet1
#df_sheet1.head()

# %%
## Read sheet 2
#df_sheet2.head()

# %%
## Read sheet 3
#df_sheet3.head()

# %%
## the DA column in sheet 1 and the login_name in sheet 2 contains the DA IDs , let's rename the ID
## to common name DA Alias and combine the cells with the common metrics.

## Rename DA column

df_sheet1=df_sheet1.rename(columns={"DA": "DA Login"})
df_sheet3=df_sheet3.rename(columns={"login_name": "DA Login"})

# %%
df_sheet1=df_sheet1.drop(columns=['Idle No Data'])

# %%
## Merge Sheet 1,2 and 3

df_merge = df_sheet2.merge(df_sheet1,on = "DA Login", how = "inner") ## combine sheet 1 and 2
df_merge = df_merge.merge(df_sheet3,on = "DA Login", how = "inner") ## combine merge(1,2) and 3
#print(df_merge.columns)
df_merge=df_merge.round(2)
print(df_merge.columns)
# Out:
# Index(['S No', 'DA Login', 'First Login Time', 'Current Status', 'UPH',
#        'AHT (In sec)', 'Velocity', 'Utilization %', 'NPT %', 'Processed Units',
#        'Production Hours', 'Non Mercury Production Hours', 'DA LoggedIn Hr',
#        'Processed Hours', 'Manual Skip Hours', 'Non Mercury Processing Hours',
#        'Staff Hours', 'NPT', 'Idle No Data', 'Training Hours', 'Lost Hours',
#        'System Issue', 'System Latency', 'Schedule Non Adherence', 'Training',
#        'Excess Break', 'Overturned Review', 'Meeting',
#        'supervisor_login_name'],
#       dtype='object')

# %%
## Performance Metrics Table
table_PM= pd.pivot_table(df_merge, values=['DA LoggedIn Hr', 'Processed Hours','Processed Units','AHT (In sec)','Velocity','Manual Skip Hours','Lost Hours'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total', aggfunc=sum , fill_value=0)
pd.set_option('display.max_rows', df_merge.shape[0]+1)
table_PM.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_beda6539_ebe7_11eb_b518_3c6aa7e4d4fe th {
#           background: #F5F5F5;
#           color: black;
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           font-weight: normal;
#           text-align: center;
#     }    #T_beda6539_ebe7_11eb_b518_3c6aa7e4d4fe td {
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           text-align: center;
#           text-align: center;
#     }    #T_beda6539_ebe7_11eb_b518_3c6aa7e4d4fe tr:nth-of-type(odd) {
#           background: white;
#     }    #T_beda6539_ebe7_11eb_b518_3c6aa7e4d4fe tr:nth-of-type(even) {
#           background: white;
#     }    #T_beda6539_ebe7_11eb_b518_3c6aa7e4d4fe tr:hover {
#           background-color: yellow;
#     }</style><table id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AHT (In sec)</th>        <th class="col_heading level0 col1" >DA LoggedIn Hr</th>        <th class="col_heading level0 col2" >Lost Hours</th>        <th class="col_heading level0 col3" >Manual Skip Hours</th>        <th class="col_heading level0 col4" >Processed Hours</th>        <th class="col_heading level0 col5" >Processed Units</th>        <th class="col_heading level0 col6" >Velocity</th>    </tr>    <tr>        <th class="index_name level0" >DA Login</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4felevel0_row0" class="row_heading level0 row0" >aafafroz</th>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow0_col0" class="data row0 col0" >37.99</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow0_col1" class="data row0 col1" >2.72</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow0_col2" class="data row0 col2" >0.00</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow0_col3" class="data row0 col3" >0.01</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow0_col4" class="data row0 col4" >2.54</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow0_col5" class="data row0 col5" >242</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow0_col6" class="data row0 col6" >94.76</td>
#             </tr>
#             <tr>
#                         <th id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4felevel0_row1" class="row_heading level0 row1" >aanbub</th>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow1_col0" class="data row1 col0" >31.40</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow1_col1" class="data row1 col1" >6.71</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow1_col2" class="data row1 col2" >1.29</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow1_col3" class="data row1 col3" >0.00</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow1_col4" class="data row1 col4" >6.70</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow1_col5" class="data row1 col5" >768</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow1_col6" class="data row1 col6" >114.65</td>
#             </tr>
#             <tr>
#                         <th id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4felevel0_row2" class="row_heading level0 row2" >aanura</th>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow2_col0" class="data row2 col0" >59.64</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow2_col1" class="data row2 col1" >6.64</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow2_col2" class="data row2 col2" >1.44</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow2_col3" class="data row2 col3" >0.00</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow2_col4" class="data row2 col4" >6.63</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow2_col5" class="data row2 col5" >400</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow2_col6" class="data row2 col6" >60.36</td>
#             </tr>
#             <tr>
#                         <th id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4felevel0_row3" class="row_heading level0 row3" >aarjk</th>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow3_col0" class="data row3 col0" >27.46</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow3_col1" class="data row3 col1" >3.62</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow3_col2" class="data row3 col2" >4.38</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow3_col3" class="data row3 col3" >0.01</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow3_col4" class="data row3 col4" >3.54</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow3_col5" class="data row3 col5" >465</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow3_col6" class="data row3 col6" >131.10</td>
#             </tr>
#             <tr>
#                         <th id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4felevel0_row4" class="row_heading level0 row4" >aasye</th>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow4_col0" class="data row4 col0" >13.52</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow4_col1" class="data row4 col1" >5.51</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow4_col2" class="data row4 col2" >2.49</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow4_col3" class="data row4 col3" >0.02</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow4_col4" class="data row4 col4" >4.50</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow4_col5" class="data row4 col5" >1202</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow4_col6" class="data row4 col6" >266.22</td>
#             </tr>
#             <tr>
#                         <th id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4felevel0_row5" class="row_heading level0 row5" >abrissac</th>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow5_col0" class="data row5 col0" >143.81</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow5_col1" class="data row5 col1" >5.72</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow5_col2" class="data row5 col2" >2.31</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow5_col3" class="data row5 col3" >0.37</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow5_col4" class="data row5 col4" >5.22</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow5_col5" class="data row5 col5" >140</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow5_col6" class="data row5 col6" >25.03</td>
#             </tr>
#             <tr>
#                         <th id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4felevel0_row6" class="row_heading level0 row6" >acjay</th>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow6_col0" class="data row6 col0" >34.22</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow6_col1" class="data row6 col1" >6.28</td>
#                         <td id="T_beda6539_ebe7_11eb_b518_3c6aa7e4d4ferow6_col2" class="data row6 col2" >2.06</td>

# %%
## NPT BreakDown Report
table_NPT= pd.pivot_table(df_merge, values=['Excess Break', 'Meeting','Training','Overturned Review'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total',aggfunc= np.sum , fill_value=0)
#pd.set_option('display.max_rows', df_sheet2.shape[0]+1)
table_NPT["sum"] = table_NPT.sum(axis=1)
table_NPT.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4fe th {
#           background: #F5F5F5;
#           color: black;
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           font-weight: normal;
#           text-align: center;
#     }    #T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4fe td {
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           text-align: center;
#           text-align: center;
#     }    #T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4fe tr:nth-of-type(odd) {
#           background: white;
#     }    #T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4fe tr:nth-of-type(even) {
#           background: white;
#     }    #T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4fe tr:hover {
#           background-color: yellow;
#     }</style><table id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Excess Break</th>        <th class="col_heading level0 col1" >Meeting</th>        <th class="col_heading level0 col2" >Overturned Review</th>        <th class="col_heading level0 col3" >Training</th>        <th class="col_heading level0 col4" >sum</th>    </tr>    <tr>        <th class="index_name level0" >DA Login</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row0" class="row_heading level0 row0" >aafafroz</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow0_col0" class="data row0 col0" >0.05</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow0_col2" class="data row0 col2" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow0_col3" class="data row0 col3" >0.93</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow0_col4" class="data row0 col4" >0.98</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row1" class="row_heading level0 row1" >aanbub</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow1_col0" class="data row1 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow1_col1" class="data row1 col1" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow1_col2" class="data row1 col2" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow1_col3" class="data row1 col3" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow1_col4" class="data row1 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row2" class="row_heading level0 row2" >aanura</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow2_col0" class="data row2 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow2_col1" class="data row2 col1" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow2_col2" class="data row2 col2" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow2_col3" class="data row2 col3" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow2_col4" class="data row2 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row3" class="row_heading level0 row3" >aarjk</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow3_col0" class="data row3 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow3_col1" class="data row3 col1" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow3_col2" class="data row3 col2" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow3_col3" class="data row3 col3" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow3_col4" class="data row3 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row4" class="row_heading level0 row4" >aasye</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow4_col0" class="data row4 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow4_col1" class="data row4 col1" >0.52</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow4_col2" class="data row4 col2" >0.33</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow4_col3" class="data row4 col3" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow4_col4" class="data row4 col4" >0.85</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row5" class="row_heading level0 row5" >abrissac</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow5_col0" class="data row5 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow5_col1" class="data row5 col1" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow5_col2" class="data row5 col2" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow5_col3" class="data row5 col3" >0.75</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow5_col4" class="data row5 col4" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row6" class="row_heading level0 row6" >acjay</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow6_col0" class="data row6 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow6_col1" class="data row6 col1" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow6_col2" class="data row6 col2" >0.29</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow6_col3" class="data row6 col3" >0.18</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow6_col4" class="data row6 col4" >0.47</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row7" class="row_heading level0 row7" >aderic</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow7_col0" class="data row7 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow7_col1" class="data row7 col1" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow7_col2" class="data row7 col2" >0.48</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow7_col3" class="data row7 col3" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow7_col4" class="data row7 col4" >0.48</td>
#             </tr>
#             <tr>
#                         <th id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4felevel0_row8" class="row_heading level0 row8" >adhyani</th>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow8_col0" class="data row8 col0" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow8_col1" class="data row8 col1" >0.57</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow8_col2" class="data row8 col2" >0.00</td>
#                         <td id="T_c800d47a_ebe7_11eb_937d_3c6aa7e4d4ferow8_col3" class="data row8 col3" >4.68</td>
#                         <

# %%
## Lost Hours Report
df_merge["Idle"]=0
table_LH= pd.pivot_table(df_merge, values=['Idle','Idle No Data','System Latency'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total',aggfunc= np.sum , fill_value=0)
#pd.set_option('display.max_rows', df_sheet2.shape[0]+1)
table_LH["Total"] = table_LH.sum(axis=1)
table_LH.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4fe th {
#           background: #F5F5F5;
#           color: black;
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           font-weight: normal;
#           text-align: center;
#     }    #T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4fe td {
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           text-align: center;
#           text-align: center;
#     }    #T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4fe tr:nth-of-type(odd) {
#           background: white;
#     }    #T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4fe tr:nth-of-type(even) {
#           background: white;
#     }    #T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4fe tr:hover {
#           background-color: yellow;
#     }</style><table id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Idle</th>        <th class="col_heading level0 col1" >Idle No Data</th>        <th class="col_heading level0 col2" >System Latency</th>        <th class="col_heading level0 col3" >Total</th>    </tr>    <tr>        <th class="index_name level0" >DA Login</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row0" class="row_heading level0 row0" >aafafroz</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow0_col2" class="data row0 col2" >0.01</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow0_col3" class="data row0 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row1" class="row_heading level0 row1" >aanbub</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow1_col1" class="data row1 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow1_col2" class="data row1 col2" >0.01</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow1_col3" class="data row1 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row2" class="row_heading level0 row2" >aanura</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow2_col0" class="data row2 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow2_col1" class="data row2 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow2_col2" class="data row2 col2" >0.01</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow2_col3" class="data row2 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row3" class="row_heading level0 row3" >aarjk</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow3_col1" class="data row3 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow3_col2" class="data row3 col2" >0.06</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow3_col3" class="data row3 col3" >0.06</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row4" class="row_heading level0 row4" >aasye</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow4_col1" class="data row4 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow4_col2" class="data row4 col2" >0.02</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow4_col3" class="data row4 col3" >0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row5" class="row_heading level0 row5" >abrissac</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow5_col1" class="data row5 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow5_col2" class="data row5 col2" >0.01</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow5_col3" class="data row5 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row6" class="row_heading level0 row6" >acjay</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow6_col1" class="data row6 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow6_col2" class="data row6 col2" >0.11</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow6_col3" class="data row6 col3" >0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row7" class="row_heading level0 row7" >aderic</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow7_col0" class="data row7 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow7_col1" class="data row7 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow7_col2" class="data row7 col2" >0.03</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow7_col3" class="data row7 col3" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row8" class="row_heading level0 row8" >adhyani</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow8_col0" class="data row8 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow8_col1" class="data row8 col1" >0.01</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow8_col2" class="data row8 col2" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow8_col3" class="data row8 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row9" class="row_heading level0 row9" >adityna</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow9_col0" class="data row9 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow9_col1" class="data row9 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow9_col2" class="data row9 col2" >0.05</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow9_col3" class="data row9 col3" >0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4felevel0_row10" class="row_heading level0 row10" >affayaz</th>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow10_col0" class="data row10 col0" >0</td>
#                         <td id="T_cd81d9b8_ebe7_11eb_8beb_3c6aa7e4d4ferow10_col1" class="data row10 col1" >0.00</td>
#                         <td id="T_cd81d9b8_ebe7_

# %%
##Utilization Report

table_UR= pd.pivot_table(df_merge, values=['Utilization %','NPT %'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total',aggfunc= np.sum , fill_value=0)
pd.set_option('display.max_rows', df_merge.shape[0]+1)
table_UR["Total"] = table_UR.sum(axis=1)
table_UR.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4fe th {
#           background: #F5F5F5;
#           color: black;
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           font-weight: normal;
#           text-align: center;
#     }    #T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4fe td {
#           font-family: verdana;
#           border-style: double;
#           border-width: thin;
#           text-align: center;
#           text-align: center;
#     }    #T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4fe tr:nth-of-type(odd) {
#           background: white;
#     }    #T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4fe tr:nth-of-type(even) {
#           background: white;
#     }    #T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4fe tr:hover {
#           background-color: yellow;
#     }</style><table id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >NPT %</th>        <th class="col_heading level0 col1" >Utilization %</th>        <th class="col_heading level0 col2" >Total</th>    </tr>    <tr>        <th class="index_name level0" >DA Login</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row0" class="row_heading level0 row0" >aafafroz</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow0_col0" class="data row0 col0" >0.02</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow0_col1" class="data row0 col1" >0.98</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow0_col2" class="data row0 col2" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row1" class="row_heading level0 row1" >aanbub</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow1_col0" class="data row1 col0" >0.00</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow1_col1" class="data row1 col1" >0.84</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow1_col2" class="data row1 col2" >0.84</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row2" class="row_heading level0 row2" >aanura</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow2_col0" class="data row2 col0" >0.00</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow2_col1" class="data row2 col1" >0.82</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow2_col2" class="data row2 col2" >0.82</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row3" class="row_heading level0 row3" >aarjk</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow3_col0" class="data row3 col0" >0.00</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow3_col1" class="data row3 col1" >0.45</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow3_col2" class="data row3 col2" >0.45</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row4" class="row_heading level0 row4" >aasye</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow4_col0" class="data row4 col0" >0.11</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow4_col1" class="data row4 col1" >0.58</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow4_col2" class="data row4 col2" >0.69</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row5" class="row_heading level0 row5" >abrissac</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow5_col0" class="data row5 col0" >0.00</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow5_col1" class="data row5 col1" >0.68</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow5_col2" class="data row5 col2" >0.68</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row6" class="row_heading level0 row6" >acjay</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow6_col0" class="data row6 col0" >0.00</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow6_col1" class="data row6 col1" >0.74</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow6_col2" class="data row6 col2" >0.74</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row7" class="row_heading level0 row7" >aderic</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow7_col0" class="data row7 col0" >0.06</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow7_col1" class="data row7 col1" >0.75</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow7_col2" class="data row7 col2" >0.81</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row8" class="row_heading level0 row8" >adhyani</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow8_col0" class="data row8 col0" >0.17</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow8_col1" class="data row8 col1" >0.34</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow8_col2" class="data row8 col2" >0.51</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row9" class="row_heading level0 row9" >adityna</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow9_col0" class="data row9 col0" >0.03</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow9_col1" class="data row9 col1" >0.72</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow9_col2" class="data row9 col2" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row10" class="row_heading level0 row10" >affayaz</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow10_col0" class="data row10 col0" >0.00</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow10_col1" class="data row10 col1" >0.36</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow10_col2" class="data row10 col2" >0.36</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row11" class="row_heading level0 row11" >agashwet</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow11_col0" class="data row11 col0" >0.12</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow11_col1" class="data row11 col1" >0.49</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow11_col2" class="data row11 col2" >0.61</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4felevel0_row12" class="row_heading level0 row12" >aggpooja</th>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow12_col0" class="data row12 col0" >0.00</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow12_col1" class="data row12 col1" >0.78</td>
#                         <td id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4ferow12_col2" class="data row12 col2" >0.78</td>
#             </tr>
#             <tr>
#                         <th id="T_d39be6f5_ebe7_11eb_b8b2_3c6aa7e4d4fel

# %%
len(table_PM.index.get_level_values('DA Login'))
# Out:
# 475

# %%
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')

#list_da = df['DA Alias'].tolist()
#list_tm = df['Level 1 Manager'].unique()

    #list = ['danijos','dmaniva','paramss','sarselv','susriram'] 
    
for j in range (0,len(table_PM.index.get_level_values('DA Login'))):
    
    table_PM= pd.pivot_table(df_merge, values=['DA LoggedIn Hr', 'Processed Hours','Processed Units','AHT (In sec)','Velocity','Manual Skip Hours','Lost Hours'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total', aggfunc=sum , fill_value=0)
    
    table_NPT= pd.pivot_table(df_merge, values=['Excess Break', 'Meeting','Training','Overturned Review'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total',aggfunc= np.sum , fill_value=0)
    table_NPT["sum"] = table_NPT.sum(axis=1)
    
    table_LH= pd.pivot_table(df_merge, values=['Idle','Idle No Data','System Latency'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total',aggfunc= np.sum , fill_value=0)

    table_LH["Total"] = table_LH.sum(axis=1)
    
    table_UR= pd.pivot_table(df_merge, values=['Utilization %','NPT %'],
                         index=['DA Login'], 
                         columns= [] ,margins=False,
                         margins_name='total',aggfunc= np.sum , fill_value=0)

    pd.set_option('display.max_rows', df_merge.shape[0]+1)

    mail = outlook.CreateItem(0)

    mail.Subject = 'Test Report'
    mail.To= 'arvinmvn@amazon.com'
    #mail.To = table_process_count.index.get_level_values('DA Alias')[j]+'@amazon.com' 
    #mail.CC = table_process_count.index.get_level_values('Level 1 Manager')[j] + '@amazon.com'
        
    
## i-> position of data in dataframe
    mail.HTMLBody ='''<h3>Test.</h3>
                   {}'''.format(table_PM[j:j+1].style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render()) + '''<h3>Test.</h3>
                   {}'''.format(table_LH[j:j+1].style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render()) + '''<h3>Test.</h3>
                   {}'''.format(table_NPT[j:j+1].style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render()) + '''<h3>Test.</h3>
                   {}'''.format(table_UR[j:j+1].style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render())
    
    ## : i + 1 increment 1 of index 
# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

    mail.Send()
