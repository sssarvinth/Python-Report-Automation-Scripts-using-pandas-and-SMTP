# %%
import time
import datetime
import os
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.ui import WebDriverWait  # available since 2.4.0
# from selenium.webdriver.support import expected_conditions as EC  # available since 2.26.0
# from selenium.webdriver.common.action_chains import ActionChains
# from selenium.common.exceptions import UnexpectedAlertPresentException
# import pandas as pd
import numpy as np
import glob
import shutil
from pathlib import Path
import warnings
import pandas as pd
from datetime import datetime as dt,timedelta as td
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)


### Variables to be updated
# duration_start = '2021-10-20'
# duration_end = '2021-10-24'

output_location = r'C:\Users\arvinmvn\Desktop\VB Lead download'
# driver_path = r'C:\Users\sinerjee\Documents\Abhilash Lead Allocation\chromedriver.exe'

today = dt.today().strftime("%Y-%m-%d")


## create a function that provides an empty file with today date as name


def make_new_directory(file_path, directory_name):
    try:
        os.makedirs(file_path + '\\' + directory_name)
    except FileExistsError:
        print(file_path + '\\' + directory_name + '  - following directory already exist')
        
make_new_directory(output_location, today)


##move the files from output location to date ymd folder

# source = output_location
# destination = output_location+'\\'+today

# files = os.listdir(source)

# for file in files:
#     new_path = shutil.move(f"{source}/{file}", destination)
#     print(new_path)


# rmUsername = 'u5695'
# rmPassword = 'vkwIE6'
# rm_url = 'https://voicerml.routevoice.com/common/view_user_list.php'
# rm_reports_page_url = 'https://voicerml.routevoice.com/common/voice/view_voice_sent_sms_list.php'

# # RM_downloaded_files = [file for file in glob.glob('\\'.join(output_location.split('\\')[:]) + "\\*")]
# # last_LA_directory = sorted(RM_downloaded_files, key=os.path.getctime, reverse=True)[1]
# # last_LA_directory
# # last_LA_date = last_LA_directory.split('\\')[-1]
# # duration_start = pd.to_datetime(last_LA_date).date().strftime('%Y-%m-%d')
# # duration_end = datetime.date.today() - datetime.timedelta(1)
# # duration_end = duration_end.strftime('%Y-%m-%d')
# # print(duration_start, duration_end)


# options = webdriver.ChromeOptions()
# options.add_argument("--start-maximized")
# options.add_argument("--start-maximized")
# options.add_argument("--disable-notifications")
# prefs = {'download.default_directory': output_location+ '\\' + today}
# options.add_experimental_option('prefs', prefs)

# driver = webdriver.Chrome(executable_path=driver_path, options=options)

# # Login to website
# driver.get(rm_url)
# time.sleep(4)

# # Enter credentials
# username = WebDriverWait(driver, 10).until(
#     EC.visibility_of_element_located((By.XPATH, '(//*[@id="username"])')))
# username.send_keys(rmUsername)

# password = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="password"])')))
# password.send_keys(rmPassword)

# login = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="loginformm"]/div[1]/p[4]/button)'))).click()
# time.sleep(4)

# # Reports page
# driver.get(rm_reports_page_url)
# time.sleep(10)


# search_button = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="sarv_main_box_contents"]/h3/div/a[1])'))).click()
# time.sleep(4)

# search_start_date = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="startdate"])')))
# ### To make the start date field editable
# driver.execute_script('document.getElementsByName("search_from_date")[0].removeAttribute("readonly")')
# search_start_date.send_keys(duration_start)
# time.sleep(2)

# search_end_date = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="enddate"])')))
# ### To make the start date field editable
# driver.execute_script('document.getElementsByName("search_to_date")[0].removeAttribute("readonly")')
# search_end_date.send_keys(duration_end)
# time.sleep(2)


# # Search Submit
# search_submit_button = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="filter-search-modal"]/form/div[2]/button[1])'))).click()
# time.sleep(4)


# # From header get total number of rows - count of row post search
# number_of_files_message_text = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="sarv_main_box_contents"]/h3/span)'))).text
# time.sleep(4)

# number_of_files = int(number_of_files_message_text.split('(')[1].split(')')[0])


# # accessing the table row as per the above count to get CampId
# CampId_list = []
# for i in range(1, number_of_files+1):
#     each_campId = WebDriverWait(driver, 10).until(
#         EC.presence_of_element_located((By.XPATH, '(//*[@id="sarv_table01"]/tbody/tr[' + str(i) + ']/td[1])'))).text
#     time.sleep(2)
# #     print(each_campId)
#     CampId_list.append(each_campId)

    
# # Using campId download the reports
# report_download_page_url = 'https://voicerml.routevoice.com/common/voice/compaign_excel_report/search_compaign_report_user.php?compaign_id='

# for each_campId in CampId_list:
#     d_url = report_download_page_url + each_campId
#     driver.get(d_url)
#     time.sleep(2)
#     each_campId_1 = WebDriverWait(driver, 10).until(
#         EC.presence_of_element_located((By.XPATH, '(/html/body/div/div/div[6]/form/table/tbody/tr/td[1]/button)')))
#     each_campId_1.click()
#     time.sleep(3)
# print('VB files download finished')

# # Logout
# driver.get(rm_reports_page_url)
# time.sleep(3)
# logout_button = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, '(//*[@id="sarv_top_head"]/div[2]/div/div/div/a[3]/i)'))).click()
# time.sleep(3)


# # In[ ]:


### Cleaning the files downloaded and collating it into single file
## create an empty datafrme and read the files

final_vb_df = pd.DataFrame()
for each_vb_file in glob.glob(output_location+'\\'+today+'\*'):
    #df = pd.read_excel(each_vb_file, sheet_name='Hot leads only', engine='openpyxl')
    df = pd.read_csv(each_vb_file)
    final_vb_df = final_vb_df.append(df)
    

## to handle the empty files replace nan as an empty string

final_vb_df[' Campaign  Name ']=final_vb_df[' Campaign  Name '].replace(np.nan,'empty')


# days to subtract from today date

d_o_s= 9

## loop to handle the empty campaign name

for i in range (0,len(final_vb_df)): 
    if final_vb_df[' Campaign  Name '].values[i]=='empty':
        if final_vb_df[' Prompts  Name '].values[i]=='Account_Management_ACOS':
            final_vb_df[' Campaign  Name '].values[i]='BOVB' + str((dt.today()-td(days=d_o_s)).strftime("%d/%m/%y")).replace('/','')
            
        if final_vb_df[' Prompts  Name '].values[i]=='Cataloging':
            final_vb_df[' Campaign  Name '].values[i]='CATVB'+str((dt.today()-td(days=d_o_s)).strftime("%d/%m/%y")).replace('/','')
            
        if final_vb_df[' Prompts  Name '].values[i]=='C_Generic':
            final_vb_df[' Campaign  Name '].values[i]='IMGVB'+str((dt.today()-td(days=d_o_s)).strftime("%d/%m/%y")).replace('/','')
            
        if final_vb_df[' Prompts  Name '].values[i]=='Amz_SR_KD':
            final_vb_df[' Campaign  Name '].values[i]='TRVB'+str((dt.today()-td(days=d_o_s)).strftime("%d/%m/%y")).replace('/','')
            
        if final_vb_df[' Prompts  Name '].values[i]=='Account Reconciliation':
            df[' Campaign  Name '].values[i]='ACVB'+str((dt.today()-td(days=d_o_s)).strftime("%d/%m/%y")).replace('/','')
            
        if final_vb_df[' Prompts  Name '].values[i]=='amz_spn_training_1stDec':
            df[' Campaign  Name '].values[i]='TRVB'+str((dt.today()-td(days=d_o_s)).strftime("%d/%m/%y")).replace('/','')    
        else:
            final_vb_df[' Prompts  Name '].values[i]='nopromptnamed'+str((dt.today()-td(days=d_o_s)).strftime("%d/%m/%y")).replace('/','')
        
    else:
        final_vb_df[' Campaign  Name '].values[i]=str(final_vb_df[' Campaign  Name '].values[i])

final_vb_df.columns = final_vb_df.columns.str.strip()
final_vb_df.columns = final_vb_df.columns.str.replace('  ', ' ')
campaign_mapping = final_vb_df[['Prompts Name', 'Campaign Name']].drop_duplicates()
campaign_mapping = campaign_mapping.loc[campaign_mapping['Campaign Name'].notna()]

final_vb_df = final_vb_df.drop(columns=['Campaign Name'])
final_vb_df = pd.merge(final_vb_df, campaign_mapping, on='Prompts Name')

final_vb_df['End Time'] = final_vb_df['End Time'].str.strip()
final_vb_df['End Time'] = final_vb_df['End Time'].str.replace('-', '')
final_vb_df['End Time'] = pd.to_datetime(final_vb_df['End Time'])

final_vb_df = final_vb_df.rename(columns={'Mobile Number': 'PhoneNo', 'End Time': 'Call End Time', 'Status': 'Call Status', 'DTMF-#2': 'DTMF Input'})
final_vb_df = final_vb_df[['PhoneNo', 'Campaign Name', 'Call End Time', 'Call Status', 'DTMF Input']].drop_duplicates()
final_vb_df =  final_vb_df.rename(columns={'DTMF-#2': 'DTMF Input'})
final_vb_df.to_csv(output_location+'\\'+today + r'/Blaster.csv', index=False)
# Out:
# C:\Users\arvinmvn\Desktop\VB Lead download\2022-01-04  - following directory already exist
# None
