# %%
##view RAW Data
import pandas as pd
import numpy as np
df= pd.read_excel(r'C:\Users\arvinmvn\Desktop\AWS SAMMI Reports\AWS Data adherence Report\AWS Verification Data Adherence Week 12.xlsx',)
df.head()
# Out:
#     User ID  Audio Length  Quality Quip  Velocity Quip
# 0  cliffpal  00:42:52.017           1.0            NaN
# 1   mhaaami  00:06:36.885           1.0            NaN
# 2   mhaaami  00:01:29.920           1.0            NaN
# 3   mhaaami  00:00:19.800           1.0            NaN
# 4  cliffpal  00:00:36.336           1.0            NaN

# %%
df.insert(2, "File Count", 1)
df.head()
# Out:
#     User ID  Audio Length  File Count  Quality Quip  Velocity Quip
# 0  cliffpal  00:42:52.017           1           1.0            NaN
# 1   mhaaami  00:06:36.885           1           1.0            NaN
# 2   mhaaami  00:01:29.920           1           1.0            NaN
# 3   mhaaami  00:00:19.800           1           1.0            NaN
# 4  cliffpal  00:00:36.336           1           1.0            NaN

# %%
##view pivot
table = pd.pivot_table(df, values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
pd.set_option('display.max_rows', df.shape[0]+1)
table
# Out:
#                        Quality Quip  Velocity Quip
# User ID  Audio Length
# cliffpal 00:00:36.336             1              1
#          00:01:03.440             1              1
#          00:01:06.966             1              1
#          00:01:15.733             1              1
#          00:01:25.896             1              1
#          00:01:30.400             1              1
#          00:02:07.640             1              1
#          00:02:50.020             1              1
#          00:06:56.880             1              1
#          00:13:46.630             1              1
#          00:20:01.818             0              1
#          00:42:52.017             1              1
# dennypau 00:00:02.800             1              1
#          00:00:03.820             1              1
#          00:00:04.080             1              1
#          00:00:07.105             1              1
#          00:00:10.000             1              1
# ...

# %%
##email to POCs/TM
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)

mail.Subject = 'AWS Verification File Upload Report'
mail.Body = 'AWS Verification File Upload Report'
#mail.HTMLBody = '<h2>This is a test message sss</h2>' #this field is optional
for column in table.iterrows():
    mail.To = 'ranrm' + '@amazon.com'
    mail.CC = 'thenmozs@amazon.com'
mail.HTMLBody = '''<h3>Hi, Please find your file uploads from the quality and velocity quip, attached below.</h3>
                   {}'''.format(table.to_html())

# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

mail.Send()

# %%
##email to DAs
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')
for i in range(0,len(table)):
    mail = outlook.CreateItem(0)

    mail.Subject = 'AWS File Upload Report'


    mail.To = str(table.index[i])+'@amazon.com' 
    mail.CC = 'thenmozs@amazon.com'
    
## i-> position of data in dataframe
    mail.HTMLBody = '''<h3>Hi, Please find processed ours for the week.</h3>
                   {}'''.format(table[i:i+1].to_html())  ## : i + 1 increment 1 of index 
# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

    mail.Send()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-16-053475f80006> in <module>
#      18 #mail.Attachments.Add(attachment)
#      19
# ---> 20     mail.Send()
#
# ~\Anaconda3\lib\site-packages\win32com\client\dynamic.py in Send(self)
#
# com_error: (-2147352567, 'Exception occurred.', (4096, 'Microsoft Outlook', 'Outlook does not recognize one or more names. ', None, 0, -2147467259), None)
