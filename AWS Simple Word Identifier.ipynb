# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\arvinmvn\Desktop\AWS SAMMI Reports\AWS Production Team user level quality report\AWS User Level Report Week 6.xlsx',)
df.head()
# Out:
#          Date  User ID Queue Name  Audio Length           File Theme  \
# 0  2021-02-09  kumrpmk   Verify 1  00:21:12.600  Prison Conversation
# 1  2021-02-09  kumrpmk   Verify 1  00:21:12.600  Prison Conversation
# 2  2021-02-09  kumrpmk   Verify 1  00:21:12.600  Prison Conversation
# 3  2021-02-09  kumrpmk   Verify 1  00:21:12.600  Prison Conversation
# 4  2021-02-09  kumrpmk   Verify 1  00:21:12.600  Prison Conversation
#
#                                Transcribed Content  \
# 0                         Ii knw what to say (()).
# 1                         Ii knw what to say (()).
# 2                         Ii knw what to say (()).
# 3  Hy, Ii wnt ai gn (()) fr ai hndred dllars (()).
# 4  Hy, Ii wnt ai gn (()) fr ai hndred dllars (()).
#
#                                     Verified Content Error Categorization  \
# 0                       Ii knw, but I'm just saying.            Listening
# 1                       Ii knw, but I'm just saying.            Listening
# ...

# %%
df2= df[['User ID', 'Transcribed Content', 'Verified Content']] 
df2.head()
# Out:
#    User ID                              Transcribed Content  \
# 0  kumrpmk                         Ii knw what to say (()).
# 1  kumrpmk                         Ii knw what to say (()).
# 2  kumrpmk                         Ii knw what to say (()).
# 3  kumrpmk  Hy, Ii wnt ai gn (()) fr ai hndred dllars (()).
# 4  kumrpmk  Hy, Ii wnt ai gn (()) fr ai hndred dllars (()).
#
#                                     Verified Content
# 0                       Ii knw, but I'm just saying.
# 1                       Ii knw, but I'm just saying.
# 2                       Ii knw, but I'm just saying.
# 3  Hy, Ii wnt ai gn and two iPhone twelve fr ai h...
# 4  Hy, Ii wnt ai gn and two iPhone twelve fr ai h...

# %%
#extract the overturned data
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
nlp = spacy.load("en_core_web_sm")
with open('AWS Transcribe Frequently occured words text file',errors="ignore") as f:
    doc= nlp(f.read())
#remove stopwords and punctuations
words = [token.text for token in doc if token.is_stop != True and token.is_punct != True]
word_freq = Counter(words)
common_words = word_freq.most_common(20)
print (common_words)

len(doc)
# Out:
# [(' ', 200), ('\n', 44), (' \n', 9), ('\n\n', 8), ('time', 4), ('bang', 4), ('\n ', 4), ('chef', 3), ('bye', 3), ('\n\n\n', 2), ('\n\n\n\n\n\n\n\n\n', 2), ('good', 2), ('cancelled', 2), ('long', 2), ('ago', 2), ('trying', 2), ('seen', 2), ('goes', 2), ('bear', 2), ('Combined#uh', 2)]
# 961

# %%
print ('hi')

# %%
from collections import Counter
counts = Counter()
for token in doc:
    counts[token.text] += 1 # Equivalently, token.text

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
nlp = spacy.load("en_core_web_sm")
with open('AWS Transcribe Frequently occured words text file',errors="ignore") as f:
    doc= nlp(f.read())
#remove stopwords and punctuations
words = [token.text for token in doc if token.is_stop != True and token.is_punct != True]
word_freq = Counter(words)
common_words = word_freq.most_common(20)
print (common_words)
# Out:
# [(' ', 173), ('\n', 92), ('breath', 21), ('\n\n', 12), ('like', 8), ('speech', 6), (' \n', 6), ('bye', 4), ('goes', 4), ('\n ', 4), ('County', 4), ('\n\n\n', 3), ('securus', 2), ('good', 2), ('>', 2), ('press', 2), ('English', 2), ('laugh', 2), ('oh', 2), ('God', 2)]
